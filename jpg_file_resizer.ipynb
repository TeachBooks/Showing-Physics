# %%
from PIL import Image
import os

def compress_image(file_path, output_quality=60):
    """ Compress the image by changing its quality. """
    picture = Image.open(file_path)
    # You can also resize the image if needed using picture.resize()
    picture.save(file_path, "JPEG", optimize=True, quality=output_quality)

def find_and_compress_images(directory, max_size=1.0*1024*1024):
    """ Find all jpg files exceeding max_size and compress them. """
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(".jpg"):
                full_path = os.path.join(root, file)
                if os.path.getsize(full_path) > max_size:
                    print(f"Compressing: {full_path}")
                    compress_image(full_path)

# Specify the root directory to start from
root_directory = 'book'
find_and_compress_images(root_directory)
# Out:
# Compressing: book\demos\demo01\demo01_figure1.JPG
# Compressing: book\demos\demo01\demo01_figure2.JPG
# Compressing: book\demos\demo02\demo02_figure2.JPG
# Compressing: book\demos\demo03\demo03_figure1.jpg
# Compressing: book\demos\demo03\demo03_figure3.jpg
# Compressing: book\demos\demo05\demo05_figure2.jpg
# Compressing: book\demos\demo06\demo06_figure2.jpg
# Compressing: book\demos\demo06\demo06_figure5.jpg
# Compressing: book\demos\demo07\demo07_figure1.jpg
# Compressing: book\demos\demo08\demo08_figure1.jpg
# Compressing: book\demos\demo08\demo08_figure2.jpg
# Compressing: book\demos\demo10\demo10_figure1.jpg
# Compressing: book\demos\demo10\demo10_figure2.jpg
# Compressing: book\demos\demo13\demo13_figure1.jpg
# Compressing: book\demos\demo20\B43_IF01_conceptcartoon.JPG
# Compressing: book\demos\demo20\B43_IF01_fig1.JPG
# Compressing: book\demos\demo20\B43_spiegelen_conceptcartoon.JPG
# Compressing: book\demos\demo22\B48_NvV07_Fig2b.jpg
# Compressing: book\demos\demo22\demo22_figure3.jpg
# Compressing: book\demos\demo23\demo23_figure3.JPG
# Compressing: book\demos\demo27\demo27_figure3.jpg
# Compressing: book\demos\demo28\demo28_figure3.jpg
# Compressing: book\demos\demo29\demo29_figure2.jpg
# Compressing: book\demos\demo30\demo30_figure1.JPG
# Compressing: book\demos\demo30\demo30_figure2.JPG
# Compressing: book\demos\demo31\demo31_figure1.jpg
# Compressing: book\demos\demo33\demo33_figure1.jpg
# Compressing: book\demos\demo33\demo33_figure2.jpg
# Compressing: book\demos\demo33\demo33_figure3.jpg
# Compressing: book\demos\demo34\09_EvdB_2.jpg
# Compressing: book\demos\demo35\44_PD_1.jpg
# Compressing: book\demos\demo35\demo35_figure1.jpg
# Compressing: book\demos\demo35\59_44oud_vallende kaars\44_PD_1.jpg
# Compressing: book\demos\demo35\59_44oud_vallende kaars\61_69oud_luchtdruk en waterdruk\69_IF_foto2_.jpg
# Compressing: book\demos\demo39\A10_WoS19_SD_figuur1.jpg
# Compressing: book\demos\demo39\A10_WoS19_SD_figuur2.jpg
# Compressing: book\demos\demo39\demo39_figure1.jpg
# Compressing: book\demos\demo40\demo40_figure1.JPG
# Compressing: book\demos\demo41\B01_FP04_conceptcartoon.JPG
# Compressing: book\demos\demo41\B01_FP04_figuur 1.JPG
# Compressing: book\demos\demo41\B01_FP04_figuur 2.JPG
# Compressing: book\demos\demo41\B01_FP04_figuur 3.JPG
# Compressing: book\demos\demo42\demo42_figure1.JPG
# Compressing: book\demos\demo44\B11_FP05_figuur 1.JPG
# Compressing: book\demos\demo44\B11_FP05_figuur 2.JPG
# Compressing: book\demos\demo44\demo44_figure2.JPG
# Compressing: book\demos\demo45\B13_FP10_figuur 1.JPG
# Compressing: book\demos\demo45\B13_FP10_figuur_2.JPG
# Compressing: book\demos\demo45\demo45_figure1.JPG
# Compressing: book\demos\demo45\demo45_figure2.JPG
# Compressing: book\demos\demo48\B35_NvV03_Fig1_wisselspanninglampje.JPG
# Compressing: book\demos\demo48\demo48_figure1.JPG
# Compressing: book\demos\demo49\B39_WoS24_SD_figuur1.jpg
# Compressing: book\demos\demo49\demo49_figure1.jpg
# Compressing: book\demos\demo50\B42_FP06_figuur 1.jpg
# Compressing: book\demos\demo50\demo50_figure1.jpg
# Compressing: book\demos\demo51\B44_LtB03_foto1.jpg
# Compressing: book\demos\demo51\B44_LtB03_foto2.jpg
# Compressing: book\demos\demo51\B44_LtB03_foto4.jpg
# Compressing: book\demos\demo51\B44_LtB3_foto3.jpg
# Compressing: book\demos\demo51\demo51_figure1.jpg
# Compressing: book\demos\demo52\B49_PF_fig1_gloeilamp als zon(fotoWS).JPG
# Compressing: book\demos\demo52\demo52_figure1.JPG
# Compressing: book\demos\demo53\demo53_figure2.jpg
# Compressing: book\demos\demo54\demo54_figure1.JPG
# Compressing: book\demos\demo54\demo54_figure2.JPG
# Compressing: book\demos\demo54\demo54_figure3A.JPG
# Compressing: book\demos\demo54\demo54_figure3B.JPG
# Compressing: book\demos\demo56\demo56_cc.JPG
# Compressing: book\demos\demo56\demo56_figure1.JPG
# Compressing: book\demos\demo56\demo56_figure3.JPG
# Compressing: book\demos\demo57\demo56_figure1B.JPG
# Compressing: book\demos\demo57\demo57_figure1.JPG
# Compressing: book\demos\demo57\demo57_figure2.JPG
# Compressing: book\demos\demo57\demo57_figure4.JPG
# Compressing: book\demos\demo58\demo58_figure1.JPG
# Compressing: book\demos\demo59\demo59_figure1.jpg
# Compressing: book\demos\demo60\KS 01 afb 2a.jpg
# Compressing: book\demos\demo60\KS 01 afb. 2b.jpg
# Compressing: book\demos\demo60\KS01_foto_1a.jpg
# Compressing: book\demos\demo60\KS01_foto_1b.jpg
# Compressing: book\demos\demo60\KS01_foto_1c.jpg
# Compressing: book\demos\demo64\demo64_figure1.JPG
# Compressing: book\demos\demo65\demo65_figure1.jpg
# Compressing: book\demos\demo68\demo68_figure1.jpg
# Compressing: book\demos\demo69\demo69_figure1.jpg
# Compressing: book\demos\demo71\demo71_figure1.jpg
# Compressing: book\demos\demo73\demo73_figure1.jpg
# Compressing: book\demos\demo73\demo73_figure2.jpg
# Compressing: book\demos\demo74\demo74_fig1.jpg
# Compressing: book\demos\demo74\demo74_fig2.jpg
# Compressing: book\demos\demo77\demo77_figure1.JPG
# Compressing: book\demos\demo77\demo77_orgiinal.JPG
# Compressing: book\demos\demo77\dm77_figure1.JPG
# Compressing: book\demos\demo78\demo78_figure1.JPG
# Compressing: book\demos\demo78\dm78_figure1.JPG
# Compressing: book\demos\demo80\dm80_figure1.jpg
# Compressing: book\demos\demo80\dm80_figure2.jpg
# Compressing: book\demos\demo81\demo81_1_figure1.jpg
# Compressing: book\demos\demo81\dm81_1_figure1.jpg
# Compressing: book\demos\demo81\B38_NV05_Zingende staaf\NV05_Figuur_1_300dpi.jpg
# Compressing: book\demos\demo84\demo84_figure1.jpg
# Compressing: book\demos\demo84\demo84_figure2.jpg
# Compressing: book\demos\demo84\dm84_figure1.jpg
# Compressing: book\demos\demo84\dm84_figure2.jpg
# Compressing: book\demos\demo85\demo85_figure2.JPG
# Compressing: book\demos\demo87\demo87_figure1.jpg
# Compressing: book\demos\demo89\demo89_figure1.jpg
# Compressing: book\demos\demo89\demo89_figure3.jpg
# Compressing: book\demos\demo89\demo89_figure4.jpg
# Compressing: book\demos\demo89\demo89_figure5.jpg
# Compressing: book\demos\demo89\demo89_figure6.jpg
# Compressing: book\demos\demo91\demo91_figure1.jpg
# Compressing: book\demos\demo94\demo94_figure1.jpg
# Compressing: book\demos\demo94\demo94_figure2.jpg
# Compressing: book\demos\demo94\demo94_figure3.JPG
# Compressing: book\demos\demo96\demo96_figure1.jpg
# Compressing: book\demos\demo96\demo96_figure4.jpg
# Compressing: book\demos\demo97\demo97_figure1.jpg
# Compressing: book\demos\demo97\demo97_figure2.jpg
# Compressing: book\demos\demo98\demo98_figure1.JPG
# Compressing: book\demos\demo98\demo98_figure2.JPG
# Compressing: book\figures\IF18_IMG_7538 (2).JPG
# Compressing: book\figures\LtB08_IMG_7531.JPG
# Compressing: book\Introduction\authors\auth_Freek.jpg
# Compressing: book\Introduction\Figures\pols.jpg
# Compressing: book\Introduction\Figures\soapbells.jpg
# Compressing: book\Pedagogy\Figures\singingrod.jpg
